# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
import json


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
test = weather_api_key
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %% [markdown]
# ---

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 605

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
units = "metric"
url = 'https://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse the JSON and retrieve data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | brokopondo
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | dudinka
# Processing Record 4 of Set 1 | santaquin
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | talnakh
# Processing Record 7 of Set 1 | mirny
# Processing Record 8 of Set 1 | jinghong
# Processing Record 9 of Set 1 | livramento do brumado
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | utrik
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | nykarleby
# Processing Record 14 of Set 1 | coracora
# Processing Record 15 of Set 1 | sisimiut
# Processing Record 16 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 17 of Set 1 | medicine hat
# Processing Record 18 of Set 1 | new plymouth
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | badger
# Processing Record 21 of Set 1 | nurabad
# Processing Record 22 of Set 1 | blackmans bay
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | kone
# Processing Record 25 of Set 1 | whitehorse
# Processing Record 26 of Set 1 | nuuk
# Processing Record 27 of Set 1 | adamstown
# Processing Record 28 of Set 1 | ati
# Processing Record 29 of Set 1 | praia da vitoria
# Processing Record 30 of Set 1 | akureyri
# Processing Record 31 of Set 1 | olgii
# City not found. Skipping...
# Processing Record 32 of Set 1 | uturoa
# Processing Record 33 of Set 1 | waitangi
# Processing Record 34 of Set 1 | sirsilla
# Processing Record 35 of Set 1 | west island
# Processing Record 36 of Set 1 | egilsstadir
# Processing Record 37 of Set 1 | roma
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | salinas
# Processing Record 41 of Set 1 | williams lake
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | n'zeto
# Processing Record 44 of Set 1 | surovikino
# Processing Record 45 of Set 1 | porbandar
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | vilyuchinsk
# Processing Record 48 of Set 1 | invercargill
# Processing Record 49 of Set 1 | inebolu
# Processing Record 50 of Set 1 | anguera
# Processing Record 0 of Set 2 | aasiaat
# Processing Record 1 of Set 2 | al jawf
# Processing Record 2 of Set 2 | ola
# Processing Record 3 of Set 2 | waynesboro
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | santa vitoria do palmar
# Processing Record 6 of Set 2 | duragan
# Processing Record 7 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 8 of Set 2 | puerto santa
# Processing Record 9 of Set 2 | krivosheino
# Processing Record 10 of Set 2 | afaahiti
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | sinop
# Processing Record 13 of Set 2 | wailua homesteads
# Processing Record 14 of Set 2 | tura
# Processing Record 15 of Set 2 | edinburgh of the seven seas
# Processing Record 16 of Set 2 | boca do acre
# Processing Record 17 of Set 2 | bilibino
# Processing Record 18 of Set 2 | yarmouth
# Processing Record 19 of Set 2 | qaqortoq
# Processing Record 20 of Set 2 | dzhangala
# Processing Record 21 of Set 2 | ta`u
# Processing Record 22 of Set 2 | mukalla
# Processing Record 23 of Set 2 | tralee
# Processing Record 24 of Set 2 | dawson creek
# Processing Record 25 of Set 2 | vallenar
# Processing Record 26 of Set 2 | nadi
# Processing Record 27 of Set 2 | olonkinbyen
# Processing Record 28 of Set 2 | byron bay
# Processing Record 29 of Set 2 | puerto natales
# Processing Record 30 of Set 2 | ouargaye
# Processing Record 31 of Set 2 | chul'man
# Processing Record 32 of Set 2 | vegreville
# Processing Record 33 of Set 2 | susuman
# Processing Record 34 of Set 2 | pedernales
# Processing Record 35 of Set 2 | hammerfest
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | kyelang
# Processing Record 38 of Set 2 | saint-francois
# Processing Record 39 of Set 2 | carauari
# Processing Record 40 of Set 2 | chui
# Processing Record 41 of Set 2 | isafjordur
# Processing Record 42 of Set 2 | gebeit
# Processing Record 43 of Set 2 | port mathurin
# Processing Record 44 of Set 2 | kill devil hills
# Processing Record 45 of Set 2 | marshall
# Processing Record 46 of Set 2 | longyearbyen
# Processing Record 47 of Set 2 | kolyvan'
# Processing Record 48 of Set 2 | tando jam
# Processing Record 49 of Set 2 | rundu
# Processing Record 0 of Set 3 | selfoss
# Processing Record 1 of Set 3 | niafunke
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | fort st. john
# Processing Record 5 of Set 3 | nelson bay
# Processing Record 6 of Set 3 | ewo
# Processing Record 7 of Set 3 | elmendorf air force base
# City not found. Skipping...
# Processing Record 8 of Set 3 | iskateley
# Processing Record 9 of Set 3 | mesudiye
# Processing Record 10 of Set 3 | ambovombe
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | san antonio de pale
# Processing Record 13 of Set 3 | moree
# Processing Record 14 of Set 3 | atafu village
# Processing Record 15 of Set 3 | prado
# Processing Record 16 of Set 3 | nikolayevsk-on-amure
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | amga
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | gulf shores
# Processing Record 21 of Set 3 | mount isa
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | akjoujt
# Processing Record 25 of Set 3 | princeville
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | saipan
# Processing Record 28 of Set 3 | alo
# Processing Record 29 of Set 3 | rocha
# Processing Record 30 of Set 3 | kwakoa
# Processing Record 31 of Set 3 | valdahon
# Processing Record 32 of Set 3 | urengoy
# Processing Record 33 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 34 of Set 3 | savave village
# City not found. Skipping...
# Processing Record 35 of Set 3 | goz beida
# Processing Record 36 of Set 3 | minot
# Processing Record 37 of Set 3 | borba
# Processing Record 38 of Set 3 | margaret river
# Processing Record 39 of Set 3 | ciudad melchor muzquiz
# Processing Record 40 of Set 3 | sale
# Processing Record 41 of Set 3 | kapuskasing
# Processing Record 42 of Set 3 | constantia
# Processing Record 43 of Set 3 | san pedro pochutla
# Processing Record 44 of Set 3 | shingu
# Processing Record 45 of Set 3 | vorgashor
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | fale old settlement
# Processing Record 48 of Set 3 | socorro
# Processing Record 49 of Set 3 | enewetak
# Processing Record 0 of Set 4 | mossel bay
# Processing Record 1 of Set 4 | miles city
# Processing Record 2 of Set 4 | boaco
# Processing Record 3 of Set 4 | perry
# Processing Record 4 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 5 of Set 4 | copiapo
# Processing Record 6 of Set 4 | hasaki
# Processing Record 7 of Set 4 | bac lieu
# Processing Record 8 of Set 4 | klyuchi
# Processing Record 9 of Set 4 | celestun
# Processing Record 10 of Set 4 | rio grande
# Processing Record 11 of Set 4 | stanley
# Processing Record 12 of Set 4 | crane
# Processing Record 13 of Set 4 | midar
# Processing Record 14 of Set 4 | puerto lempira
# Processing Record 15 of Set 4 | cadale
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | artesia
# Processing Record 18 of Set 4 | alakurtti
# Processing Record 19 of Set 4 | magistral'nyy
# Processing Record 20 of Set 4 | veseloyarsk
# Processing Record 21 of Set 4 | huangnihe
# Processing Record 22 of Set 4 | ilulissat
# Processing Record 23 of Set 4 | sabang
# Processing Record 24 of Set 4 | le vauclin
# Processing Record 25 of Set 4 | south hedland
# Processing Record 26 of Set 4 | kimbe
# Processing Record 27 of Set 4 | marine corps base hawaii - mcbh
# Processing Record 28 of Set 4 | arkhangel'sk
# Processing Record 29 of Set 4 | fisterra
# Processing Record 30 of Set 4 | mugia
# Processing Record 31 of Set 4 | riosucio
# Processing Record 32 of Set 4 | bredasdorp
# Processing Record 33 of Set 4 | ribeira grande
# Processing Record 34 of Set 4 | gaigeturi
# Processing Record 35 of Set 4 | remire-montjoly
# Processing Record 36 of Set 4 | shentala
# Processing Record 37 of Set 4 | pandan
# Processing Record 38 of Set 4 | faaa
# Processing Record 39 of Set 4 | papatowai
# Processing Record 40 of Set 4 | al bawiti
# Processing Record 41 of Set 4 | college
# Processing Record 42 of Set 4 | takoradi
# Processing Record 43 of Set 4 | carnarvon
# Processing Record 44 of Set 4 | james island
# City not found. Skipping...
# Processing Record 45 of Set 4 | keflavik
# Processing Record 46 of Set 4 | fu'an
# Processing Record 47 of Set 4 | heroica ciudad de tlaxiaco
# Processing Record 48 of Set 4 | cabo san lucas
# Processing Record 49 of Set 4 | nar'yan-mar
# Processing Record 0 of Set 5 | hilo
# Processing Record 1 of Set 5 | hawaiian paradise park
# Processing Record 2 of Set 5 | nowy dwor gdanski
# Processing Record 3 of Set 5 | kerikeri
# Processing Record 4 of Set 5 | mata-utu
# Processing Record 5 of Set 5 | tyup
# Processing Record 6 of Set 5 | fort bragg
# Processing Record 7 of Set 5 | iwanai
# Processing Record 8 of Set 5 | lompoc
# Processing Record 9 of Set 5 | cockburn town
# Processing Record 10 of Set 5 | bethanie
# Processing Record 11 of Set 5 | ujae
# Processing Record 12 of Set 5 | ayorou
# Processing Record 13 of Set 5 | puerto baquerizo moreno
# Processing Record 14 of Set 5 | cat ba
# City not found. Skipping...
# Processing Record 15 of Set 5 | tafuna
# Processing Record 16 of Set 5 | chibougamau
# Processing Record 17 of Set 5 | qui nhon
# Processing Record 18 of Set 5 | adrar
# Processing Record 19 of Set 5 | ust-nera
# Processing Record 20 of Set 5 | thunder bay
# Processing Record 21 of Set 5 | chipinge
# Processing Record 22 of Set 5 | inhambane
# Processing Record 23 of Set 5 | quellon
# Processing Record 24 of Set 5 | punta arenas
# Processing Record 25 of Set 5 | badr hunayn
# Processing Record 26 of Set 5 | luderitz
# Processing Record 27 of Set 5 | san agustin de valle fertil
# Processing Record 28 of Set 5 | at taj
# Processing Record 29 of Set 5 | wuzhou
# Processing Record 30 of Set 5 | rongelap
# Processing Record 31 of Set 5 | kiunga
# Processing Record 32 of Set 5 | bayji
# Processing Record 33 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 34 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 35 of Set 5 | inari
# Processing Record 36 of Set 5 | rio gallegos
# Processing Record 37 of Set 5 | brisas de zicatela
# Processing Record 38 of Set 5 | kamyzyak
# Processing Record 39 of Set 5 | n'dalatando
# Processing Record 40 of Set 5 | alofi
# Processing Record 41 of Set 5 | ntoum
# Processing Record 42 of Set 5 | jiangyou
# Processing Record 43 of Set 5 | richards bay
# Processing Record 44 of Set 5 | namsos
# Processing Record 45 of Set 5 | faya-largeau
# Processing Record 46 of Set 5 | puerto ayacucho
# Processing Record 47 of Set 5 | pasni
# Processing Record 48 of Set 5 | sinjai
# Processing Record 49 of Set 5 | whangarei
# Processing Record 0 of Set 6 | kangding
# Processing Record 1 of Set 6 | meizhou
# Processing Record 2 of Set 6 | kuqa
# Processing Record 3 of Set 6 | massawa
# Processing Record 4 of Set 6 | errachidia
# Processing Record 5 of Set 6 | nova sintra
# Processing Record 6 of Set 6 | mount pearl
# Processing Record 7 of Set 6 | nemuro
# Processing Record 8 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 9 of Set 6 | fauske
# Processing Record 10 of Set 6 | newala kisimani
# Processing Record 11 of Set 6 | whitecourt
# Processing Record 12 of Set 6 | neiafu
# Processing Record 13 of Set 6 | dawei
# Processing Record 14 of Set 6 | bratsk
# Processing Record 15 of Set 6 | buta
# Processing Record 16 of Set 6 | nyurba
# Processing Record 17 of Set 6 | saint croix
# Processing Record 18 of Set 6 | bontang
# Processing Record 19 of Set 6 | wynyard
# Processing Record 20 of Set 6 | bogale
# Processing Record 21 of Set 6 | porto belo
# Processing Record 22 of Set 6 | bikenibeu village
# Processing Record 23 of Set 6 | gondar
# Processing Record 24 of Set 6 | tabas
# Processing Record 25 of Set 6 | belyy yar
# Processing Record 26 of Set 6 | okhotsk
# Processing Record 27 of Set 6 | darwin
# Processing Record 28 of Set 6 | ishinomaki
# Processing Record 29 of Set 6 | swakopmund
# Processing Record 30 of Set 6 | hadsund
# Processing Record 31 of Set 6 | lihue
# Processing Record 32 of Set 6 | bitam
# Processing Record 33 of Set 6 | okha
# Processing Record 34 of Set 6 | pariaman
# Processing Record 35 of Set 6 | yatou
# Processing Record 36 of Set 6 | sona
# Processing Record 37 of Set 6 | la foa
# Processing Record 38 of Set 6 | asaita
# Processing Record 39 of Set 6 | margate
# Processing Record 40 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 41 of Set 6 | harper
# Processing Record 42 of Set 6 | denton holme
# Processing Record 43 of Set 6 | tateyama
# Processing Record 44 of Set 6 | happy valley-goose bay
# Processing Record 45 of Set 6 | aykhal
# Processing Record 46 of Set 6 | tangalle
# Processing Record 47 of Set 6 | male
# Processing Record 48 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 49 of Set 6 | uckfield
# Processing Record 0 of Set 7 | mount gambier
# Processing Record 1 of Set 7 | gueltat zemmour
# City not found. Skipping...
# Processing Record 2 of Set 7 | chonchi
# Processing Record 3 of Set 7 | castillos
# Processing Record 4 of Set 7 | broome
# Processing Record 5 of Set 7 | kununurra
# Processing Record 6 of Set 7 | ponta delgada
# Processing Record 7 of Set 7 | brooks
# Processing Record 8 of Set 7 | masterton
# Processing Record 9 of Set 7 | basco
# Processing Record 10 of Set 7 | orkney
# Processing Record 11 of Set 7 | touros
# Processing Record 12 of Set 7 | tocopilla
# Processing Record 13 of Set 7 | nova vicosa
# Processing Record 14 of Set 7 | san fernando de apure
# Processing Record 15 of Set 7 | alamosa
# Processing Record 16 of Set 7 | anadyr
# Processing Record 17 of Set 7 | east ballina
# Processing Record 18 of Set 7 | klaksvik
# Processing Record 19 of Set 7 | ilheus
# Processing Record 20 of Set 7 | voitsberg
# Processing Record 21 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 22 of Set 7 | ogoja
# Processing Record 23 of Set 7 | necochea
# Processing Record 24 of Set 7 | vila velha
# Processing Record 25 of Set 7 | plav
# Processing Record 26 of Set 7 | barra dos coqueiros
# Processing Record 27 of Set 7 | russkaya polyana
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | udachny
# Processing Record 30 of Set 7 | dickinson
# Processing Record 31 of Set 7 | hamilton
# Processing Record 32 of Set 7 | foumbot
# Processing Record 33 of Set 7 | brak
# Processing Record 34 of Set 7 | am timan
# Processing Record 35 of Set 7 | imbituba
# Processing Record 36 of Set 7 | whitstable
# Processing Record 37 of Set 7 | tindouf
# Processing Record 38 of Set 7 | al kharijah
# Processing Record 39 of Set 7 | new norfolk
# Processing Record 40 of Set 7 | solikamsk
# Processing Record 41 of Set 7 | sadaseopet
# Processing Record 42 of Set 7 | bam
# Processing Record 43 of Set 7 | dera ghazi khan
# Processing Record 44 of Set 7 | pocone
# Processing Record 45 of Set 7 | naze
# Processing Record 46 of Set 7 | bastogne
# Processing Record 47 of Set 7 | grand-lahou
# Processing Record 48 of Set 7 | santa elena de uairen
# Processing Record 49 of Set 7 | marrakesh
# Processing Record 0 of Set 8 | awjilah
# Processing Record 1 of Set 8 | cohoes
# Processing Record 2 of Set 8 | mendoza
# Processing Record 3 of Set 8 | dunedin
# Processing Record 4 of Set 8 | smithers
# Processing Record 5 of Set 8 | holualoa
# Processing Record 6 of Set 8 | samalut
# Processing Record 7 of Set 8 | bandar
# Processing Record 8 of Set 8 | palmer
# Processing Record 9 of Set 8 | ukiah
# Processing Record 10 of Set 8 | gadzhiyevo
# Processing Record 11 of Set 8 | kingston
# Processing Record 12 of Set 8 | la'ie
# Processing Record 13 of Set 8 | wanning
# Processing Record 14 of Set 8 | gaiman
# Processing Record 15 of Set 8 | al ghayzah
# Processing Record 16 of Set 8 | naifaru
# Processing Record 17 of Set 8 | beau vallon
# Processing Record 18 of Set 8 | dolbeau-mistassini
# Processing Record 19 of Set 8 | san julian
# Processing Record 20 of Set 8 | chancay
# Processing Record 21 of Set 8 | fort portal
# Processing Record 22 of Set 8 | howrah
# Processing Record 23 of Set 8 | cururupu
# Processing Record 24 of Set 8 | codrington
# Processing Record 25 of Set 8 | stornoway
# Processing Record 26 of Set 8 | shahba
# Processing Record 27 of Set 8 | salahonda
# Processing Record 28 of Set 8 | oamaru
# Processing Record 29 of Set 8 | lycksele
# Processing Record 30 of Set 8 | greymouth
# Processing Record 31 of Set 8 | rock springs
# Processing Record 32 of Set 8 | miches
# Processing Record 33 of Set 8 | kidal
# Processing Record 34 of Set 8 | pula
# Processing Record 35 of Set 8 | albu kamal
# Processing Record 36 of Set 8 | odienne
# Processing Record 37 of Set 8 | gamba
# Processing Record 38 of Set 8 | kourou
# Processing Record 39 of Set 8 | preobrazheniye
# Processing Record 40 of Set 8 | pangkalan brandan
# Processing Record 41 of Set 8 | bandarbeyla
# Processing Record 42 of Set 8 | tanda
# Processing Record 43 of Set 8 | nkurenkuru
# City not found. Skipping...
# Processing Record 44 of Set 8 | kodinsk
# Processing Record 45 of Set 8 | mahajanga
# Processing Record 46 of Set 8 | iwon-up
# Processing Record 47 of Set 8 | sandnessjoen
# Processing Record 48 of Set 8 | yugorsk
# Processing Record 49 of Set 8 | xilin hot
# Processing Record 0 of Set 9 | ouellah
# City not found. Skipping...
# Processing Record 1 of Set 9 | antofagasta
# Processing Record 2 of Set 9 | leduc
# Processing Record 3 of Set 9 | santiago de cao
# Processing Record 4 of Set 9 | haifa
# Processing Record 5 of Set 9 | la malbaie
# Processing Record 6 of Set 9 | anjozorobe
# Processing Record 7 of Set 9 | alderetes
# Processing Record 8 of Set 9 | kasama
# Processing Record 9 of Set 9 | popondetta
# Processing Record 10 of Set 9 | urangan
# Processing Record 11 of Set 9 | plouzane
# Processing Record 12 of Set 9 | kailua-kona
# Processing Record 13 of Set 9 | hailar
# Processing Record 14 of Set 9 | taskopru
# Processing Record 15 of Set 9 | besisahar
# Processing Record 16 of Set 9 | salmon arm
# Processing Record 17 of Set 9 | sao jose do belmonte
# Processing Record 18 of Set 9 | bodden town
# Processing Record 19 of Set 9 | sen monorom
# Processing Record 20 of Set 9 | haiku-pauwela
# Processing Record 21 of Set 9 | forster
# Processing Record 22 of Set 9 | san patricio
# Processing Record 23 of Set 9 | caleta de carquin
# Processing Record 24 of Set 9 | darhan
# Processing Record 25 of Set 9 | monterrey
# Processing Record 26 of Set 9 | nema
# Processing Record 27 of Set 9 | ketchikan
# Processing Record 28 of Set 9 | mahanoro
# Processing Record 29 of Set 9 | tasgaon
# Processing Record 30 of Set 9 | grand gaube
# Processing Record 31 of Set 9 | port saint john's
# Processing Record 32 of Set 9 | pangoa
# Processing Record 33 of Set 9 | oeiras do para
# Processing Record 34 of Set 9 | tazovsky
# Processing Record 35 of Set 9 | saudarkrokur
# Processing Record 36 of Set 9 | qamdo
# Processing Record 37 of Set 9 | karratha
# Processing Record 38 of Set 9 | malakal
# Processing Record 39 of Set 9 | cidade velha
# Processing Record 40 of Set 9 | vuktyl
# Processing Record 41 of Set 9 | burutu
# Processing Record 42 of Set 9 | port elizabeth
# Processing Record 43 of Set 9 | genhe
# Processing Record 44 of Set 9 | katsuura
# Processing Record 45 of Set 9 | dabakala
# Processing Record 46 of Set 9 | kasangulu
# Processing Record 47 of Set 9 | namibe
# Processing Record 48 of Set 9 | bartin
# Processing Record 49 of Set 9 | mios
# Processing Record 0 of Set 10 | san jose village
# City not found. Skipping...
# Processing Record 1 of Set 10 | boudjima
# Processing Record 2 of Set 10 | tabuk
# Processing Record 3 of Set 10 | mhamid
# Processing Record 4 of Set 10 | lerwick
# Processing Record 5 of Set 10 | beloyarskiy
# Processing Record 6 of Set 10 | trairi
# Processing Record 7 of Set 10 | sinjar
# Processing Record 8 of Set 10 | mariental
# Processing Record 9 of Set 10 | sao vicente
# Processing Record 10 of Set 10 | nampula
# Processing Record 11 of Set 10 | kaltungo
# Processing Record 12 of Set 10 | al mijlad
# Processing Record 13 of Set 10 | ust'-talovka
# Processing Record 14 of Set 10 | magadan
# Processing Record 15 of Set 10 | safford
# Processing Record 16 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 10 | gobabis
# Processing Record 18 of Set 10 | chinoz
# Processing Record 19 of Set 10 | walvis bay
# Processing Record 20 of Set 10 | virginia beach
# Processing Record 21 of Set 10 | waingapu
# Processing Record 22 of Set 10 | trincomalee
# Processing Record 23 of Set 10 | aripuana
# Processing Record 24 of Set 10 | red hill
# Processing Record 25 of Set 10 | luanshya
# Processing Record 26 of Set 10 | opuwo
# Processing Record 27 of Set 10 | beidao
# Processing Record 28 of Set 10 | isiolo
# Processing Record 29 of Set 10 | al wakrah
# Processing Record 30 of Set 10 | qaisumah
# Processing Record 31 of Set 10 | prainha
# Processing Record 32 of Set 10 | federal
# Processing Record 33 of Set 10 | mahmutlar
# Processing Record 34 of Set 10 | uyskoye
# Processing Record 35 of Set 10 | atar
# Processing Record 36 of Set 10 | bentiu
# Processing Record 37 of Set 10 | turpan
# Processing Record 38 of Set 10 | lagoa
# Processing Record 39 of Set 10 | ialibu
# Processing Record 40 of Set 10 | ulety
# Processing Record 41 of Set 10 | arteche
# Processing Record 42 of Set 10 | huntsville
# Processing Record 43 of Set 10 | erenhot
# Processing Record 44 of Set 10 | colonia
# Processing Record 45 of Set 10 | ulladulla
# Processing Record 46 of Set 10 | geneseo
# Processing Record 47 of Set 10 | solleftea
# Processing Record 48 of Set 10 | kodinar
# Processing Record 49 of Set 10 | ohara
# Processing Record 0 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 1 of Set 11 | peace river
# Processing Record 2 of Set 11 | tuba city
# Processing Record 3 of Set 11 | coquimbo
# Processing Record 4 of Set 11 | vylkove
# Processing Record 5 of Set 11 | monrovia
# Processing Record 6 of Set 11 | greenland
# Processing Record 7 of Set 11 | oodweyne
# Processing Record 8 of Set 11 | taytay
# Processing Record 9 of Set 11 | nzega
# Processing Record 10 of Set 11 | tarawa
# Processing Record 11 of Set 11 | kitimat
# Processing Record 12 of Set 11 | arroyito
# Processing Record 13 of Set 11 | tingi
# Processing Record 14 of Set 11 | sabalgarh
# Processing Record 15 of Set 11 | namtsy
# Processing Record 16 of Set 11 | timimoun
# Processing Record 17 of Set 11 | priargunsk
# Processing Record 18 of Set 11 | kalemie
# Processing Record 19 of Set 11 | cable beach
# City not found. Skipping...
# Processing Record 20 of Set 11 | sechura
# Processing Record 21 of Set 11 | barwani
# Processing Record 22 of Set 11 | koppal
# Processing Record 23 of Set 11 | bel ombre
# Processing Record 24 of Set 11 | paramaribo
# Processing Record 25 of Set 11 | dikwa
# Processing Record 26 of Set 11 | tamanrasset
# Processing Record 27 of Set 11 | baxter
# Processing Record 28 of Set 11 | portland
# Processing Record 29 of Set 11 | puerto armuelles
# Processing Record 30 of Set 11 | sinabang
# Processing Record 31 of Set 11 | palasa
# Processing Record 32 of Set 11 | haimen
# Processing Record 33 of Set 11 | fada
# Processing Record 34 of Set 11 | banda aceh
# Processing Record 35 of Set 11 | itoman
# Processing Record 36 of Set 11 | mont-laurier
# Processing Record 37 of Set 11 | cabedelo
# Processing Record 38 of Set 11 | tadine
# Processing Record 39 of Set 11 | jayapura
# Processing Record 40 of Set 11 | lorengau
# Processing Record 41 of Set 11 | manati
# Processing Record 42 of Set 11 | mil'kovo
# Processing Record 43 of Set 11 | copala
# Processing Record 44 of Set 11 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 45 of Set 11 | mary
# Processing Record 46 of Set 11 | formosa do rio preto
# Processing Record 47 of Set 11 | hami
# Processing Record 48 of Set 11 | marsh harbour
# Processing Record 49 of Set 11 | alnashi
# Processing Record 0 of Set 12 | alotau
# Processing Record 1 of Set 12 | luwuk
# Processing Record 2 of Set 12 | flying fish cove
# Processing Record 3 of Set 12 | sittwe
# Processing Record 4 of Set 12 | pontes e lacerda
# Processing Record 5 of Set 12 | vila franca do campo
# Processing Record 6 of Set 12 | ishigaki
# Processing Record 7 of Set 12 | heroica caborca
# Processing Record 8 of Set 12 | akrehamn
# Processing Record 9 of Set 12 | arsen'yev
# Processing Record 10 of Set 12 | marabba
# Processing Record 11 of Set 12 | kiffa
# Processing Record 12 of Set 12 | chiredzi
# Processing Record 13 of Set 12 | acarau
# Processing Record 14 of Set 12 | muynoq
# Processing Record 15 of Set 12 | patacamaya
# Processing Record 16 of Set 12 | port-vila
# Processing Record 17 of Set 12 | road town
# Processing Record 18 of Set 12 | hengchun
# Processing Record 19 of Set 12 | gornozavodsk
# Processing Record 20 of Set 12 | tucuma
# Processing Record 21 of Set 12 | ebon
# Processing Record 22 of Set 12 | horta
# Processing Record 23 of Set 12 | vanadzor
# Processing Record 24 of Set 12 | timmins
# Processing Record 25 of Set 12 | vrangel'
# Processing Record 26 of Set 12 | ocean pointe
# City not found. Skipping...
# Processing Record 27 of Set 12 | piti village
# Processing Record 28 of Set 12 | chinchilla
# Processing Record 29 of Set 12 | zheleznodorozhnyy
# Processing Record 30 of Set 12 | labytnangi
# Processing Record 31 of Set 12 | cestos city
# Processing Record 32 of Set 12 | inverell
# Processing Record 33 of Set 12 | minas de marcona
# Processing Record 34 of Set 12 | andapa
# Processing Record 35 of Set 12 | palapag
# Processing Record 36 of Set 12 | gelemso
# Processing Record 37 of Set 12 | den burg
# Processing Record 38 of Set 12 | nova olimpia
# Processing Record 39 of Set 12 | altai
# Processing Record 40 of Set 12 | loukhi
# Processing Record 41 of Set 12 | lautoka
# Processing Record 42 of Set 12 | igarka
# Processing Record 43 of Set 12 | dolores
# Processing Record 44 of Set 12 | bizhbulyak
# Processing Record 45 of Set 12 | alice springs
# Processing Record 46 of Set 12 | saint-philippe
# Processing Record 47 of Set 12 | barsovo
# Processing Record 48 of Set 12 | kristiansund
# Processing Record 49 of Set 12 | ayaguz
# City not found. Skipping...
# Processing Record 0 of Set 13 | cafayate
# Processing Record 1 of Set 13 | nizhnesortymskiy
# Processing Record 2 of Set 13 | dabwali
# Processing Record 3 of Set 13 | santona
# Processing Record 4 of Set 13 | heroica guaymas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
print(city_data_df.count())
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       brokopondo   4.7500  -55.1667     25.83        82          50
# 1  arraial do cabo -22.9661  -42.0278     21.74        92          67
# 2          dudinka  69.4058   86.1778     -2.39        97         100
# 3        santaquin  39.9755 -111.7852     11.03        87         100
# 4           avarua -21.2078 -159.7750     24.03        73          40
#
#    Wind Speed Country        Date
# 0        4.53      SR  1729220531
# 1        3.66      BR  1729220376
# 2        5.67      RU  1729220212
# 3        1.79      US  1729220534
# 4        3.60      CK  1729220046

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             brokopondo   4.7500  -55.1667     25.83        82          50
# 1        arraial do cabo -22.9661  -42.0278     21.74        92          67
# 2                dudinka  69.4058   86.1778     -2.39        97         100
# 3              santaquin  39.9755 -111.7852     11.03        87         100
# 4                 avarua -21.2078 -159.7750     24.03        73          40
#
#          Wind Speed Country        Date
# City_ID
# 0              4.53      SR  1729220531
# 1              3.66      BR  1729220376
# 2              5.67      RU  1729220212
# 3              1.79      US  1729220534
# 4              3.60      CK  1729220046

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Create the output directory if it doesn't exist
output_dir = "../output_data"
os.makedirs(output_dir, exist_ok=True)

# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title('City Latitude vs.Temperature')
plt.grid()

# Save the figure
plt.savefig(os.path.join(output_dir, "Fig1.png"))

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker='o', edgecolor='grey')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs.Humidity')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs.Cloudiness')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title('City Latitude vs.Wind Speed')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x_axis, y_axis,eq_loc):  
    correlation = st.pearsonr(x_axis,y_axis)
    p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
    p_fit = p_slope * x_axis + p_int
    eq= f"y ={p_slope: .2f}x +{ p_int: .2f}"
       
    #Plot the line
    plt.scatter(x_axis, y_axis ,marker="o")
    plt.plot(x_axis,p_fit,"--", color='red')
    plt.annotate(eq, eq_loc, fontsize=12, color='red')
    print(f"The r-value between {x_axis.name} and {y_axis.name} is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        brokopondo   4.7500  -55.1667     25.83        82          50
# 2           dudinka  69.4058   86.1778     -2.39        97         100
# 3         santaquin  39.9755 -111.7852     11.03        87         100
# 5           talnakh  69.4865   88.3972     -6.10        94         100
# 6             mirny  62.5353  113.9611     -9.22        78          33
#
#          Wind Speed Country        Date
# City_ID
# 0              4.53      SR  1729220531
# 2              5.67      RU  1729220212
# 3              1.79      US  1729220534
# 5              6.31      RU  1729220159
# 6              3.61      RU  1729220538

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1              arraial do cabo -22.9661  -42.0278     21.74        92
# 4                       avarua -21.2078 -159.7750     24.03        73
# 8        livramento do brumado -13.6431  -41.8406     21.42        93
# 9                    grytviken -54.2811  -36.5092      4.20        75
# 11           port-aux-francais -49.3500   70.2167      2.04        72
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                67        3.66      BR  1729220376
# 4                40        3.60      CK  1729220046
# 8                88        1.28      BR  1729220541
# 9               100        3.49      GS  1729220061
# 11               77       13.63      TF  1729220057

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],(10, -10))
plt.xlabel('Latitude')
plt.ylabel('Temp(C)')
# Out:
# The r-value between Lat and Max Temp is -0.85
# Text(0, 0.5, 'Temp(C)')

# %%
# Linear regression on Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],(-30, 5))
plt.xlabel('Latitude')
plt.ylabel('Temp(C)')
# Out:
# The r-value between Lat and Max Temp is 0.67
# Text(0, 0.5, 'Temp(C)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],(55, 10))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
# Out:
# The r-value between Lat and Humidity is 0.12
# Text(0, 0.5, 'Humidity(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],(-50, 25))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
# Out:
# The r-value between Lat and Humidity is -0.04
# Text(0, 0.5, 'Humidity(%)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],(50, 50))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
# Out:
# The r-value between Lat and Cloudiness is 0.06
# Text(0, 0.5, 'Cloudiness(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],(-50, 65))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
# Out:
# The r-value between Lat and Cloudiness is -0.11
# Text(0, 0.5, 'Cloudiness(%)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],(10, 12))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
# Out:
# The r-value between Lat and Wind Speed is 0.16
# Text(0, 0.5, 'Wind Speed(m/s)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],(-50, 9))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
# Out:
# The r-value between Lat and Wind Speed is -0.11
# Text(0, 0.5, 'Wind Speed(m/s)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
The wind speeds are averaged across all latitudes of the northern and southern hemispheres. But was it interesting
is that there are a few outlyiers of greater speeds the further you get from 0 degrees or the equator.
